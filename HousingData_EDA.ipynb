# %% [markdown]
# <a href="https://colab.research.google.com/github/women-in-ai-ireland/September-2022-CeADAR-Group-002/blob/main/HousingData_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv ("/HousingData.csv")

# %%
df.head()
# Out:
#    County Quarter  New_Dwelling_Completion_Number  Volume_of_Sales_Number  \
# 0  Carlow  2011Q1                              17                    50.0
# 1  Carlow  2011Q2                              24                    59.0
# 2  Carlow  2011Q3                              24                    62.0
# 3  Carlow  2011Q4                              38                    74.0
# 4  Carlow  2012Q1                              17                    48.0
#
#    Value_of_Sales_MilEuro  Median_Price_Euro  Mean_Price_Euro  \
# 0                     6.8      153205.000000    136542.666667
# 1                     6.6      110000.000000    111140.666667
# 2                     5.9       77833.333333     96286.000000
# 3                     6.1       71848.333333     81263.000000
# 4                     3.9       77666.666667     80014.000000
#
#    Housing_Stock_Number  Vacant_House_Number
# 0              23165.00               3202.0
# 1              23165.00               3202.0
# ...

# %%
df.tail()
# Out:
#        County Quarter  New_Dwelling_Completion_Number  Volume_of_Sales_Number  \
# 1191  Wicklow  2021Q2                             149                   526.0
# 1192  Wicklow  2021Q3                             229                   639.0
# 1193  Wicklow  2021Q4                             239                   697.0
# 1194  Wicklow  2022Q1                             268                   420.0
# 1195  Wicklow  2022Q2                             332                   591.0
#
#       Value_of_Sales_MilEuro  Median_Price_Euro  Mean_Price_Euro  \
# 1191                   186.2      323500.000000    348426.000000
# 1192                   250.5      342500.000000    392000.333333
# 1193                   281.5      375116.333333    401860.333333
# 1194                   151.1      337367.666667    361707.000000
# 1195                   255.4      403888.666667    431266.333333
#
#       Housing_Stock_Number  Vacant_House_Number
# 1191             59258.500             4446.500
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1196 entries, 0 to 1195
# Data columns (total 9 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   County                          1196 non-null   object
#  1   Quarter                         1196 non-null   object
#  2   New_Dwelling_Completion_Number  1196 non-null   int64
#  3   Volume_of_Sales_Number          1196 non-null   float64
#  4   Value_of_Sales_MilEuro          1196 non-null   float64
#  5   Median_Price_Euro               1196 non-null   float64
#  6   Mean_Price_Euro                 1196 non-null   float64
#  7   Housing_Stock_Number            1196 non-null   float64
#  8   Vacant_House_Number             1196 non-null   float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 84.2+ KB

# %%
df.shape
# Out:
# (1196, 9)

# %%
df.size
# Out:
# 10764

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#        New_Dwelling_Completion_Number  Volume_of_Sales_Number  \
# count                     1196.000000             1196.000000
# mean                       122.822742              497.910535
# std                        252.015415              851.437229
# min                          5.000000               33.000000
# 25%                         29.000000              164.000000
# 50%                         54.000000              274.000000
# 75%                        113.000000              464.000000
# max                       2729.000000             7460.000000
#
#        Value_of_Sales_MilEuro  Median_Price_Euro  Mean_Price_Euro  \
# count             1196.000000        1196.000000      1196.000000
# mean               115.828595      136231.114548    149359.146321
# std                322.103722       67387.761308     70535.755046
# min                  1.600000       26045.666667     50745.333333
# 25%                 17.275000       86791.666667    101088.250000
# ...

# %%
df.sample()
# Out:
#        County Quarter  New_Dwelling_Completion_Number  Volume_of_Sales_Number  \
# 603  Longford  2012Q2                              24                    53.0
#
#      Value_of_Sales_MilEuro  Median_Price_Euro  Mean_Price_Euro  \
# 603                     3.2       40720.333333          58120.0
#
#      Housing_Stock_Number  Vacant_House_Number
# 603               18776.6               3880.4

# %%
df.isnull().sum()
# Out:
# County                            0
# Quarter                           0
# New_Dwelling_Completion_Number    0
# Volume_of_Sales_Number            0
# Value_of_Sales_MilEuro            0
# Median_Price_Euro                 0
# Mean_Price_Euro                   0
# Housing_Stock_Number              0
# Vacant_House_Number               0
# dtype: int64

# %%
df.nunique()
# Out:
# County                              26
# Quarter                             46
# New_Dwelling_Completion_Number     295
# Volume_of_Sales_Number             620
# Value_of_Sales_MilEuro             780
# Median_Price_Euro                 1039
# Mean_Price_Euro                   1194
# Housing_Stock_Number              1170
# Vacant_House_Number               1166
# dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1196, step=1)

# %%
df.columns
# Out:
# Index(['County', 'Quarter', 'New_Dwelling_Completion_Number',
#        'Volume_of_Sales_Number', 'Value_of_Sales_MilEuro', 'Median_Price_Euro',
#        'Mean_Price_Euro', 'Housing_Stock_Number', 'Vacant_House_Number'],
#       dtype='object')

# %%
df.dropna()
# Out:
#        County Quarter  New_Dwelling_Completion_Number  Volume_of_Sales_Number  \
# 0      Carlow  2011Q1                              17                    50.0
# 1      Carlow  2011Q2                              24                    59.0
# 2      Carlow  2011Q3                              24                    62.0
# 3      Carlow  2011Q4                              38                    74.0
# 4      Carlow  2012Q1                              17                    48.0
# ...       ...     ...                             ...                     ...
# 1191  Wicklow  2021Q2                             149                   526.0
# 1192  Wicklow  2021Q3                             229                   639.0
# 1193  Wicklow  2021Q4                             239                   697.0
# 1194  Wicklow  2022Q1                             268                   420.0
# 1195  Wicklow  2022Q2                             332                   591.0
#
# ...

# %%
df.shape
# Out:
# (1196, 9)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1191    False
# 1192    False
# 1193    False
# 1194    False
# 1195    False
# Length: 1196, dtype: bool

# %%
df.value_counts()
# Out:
# County    Quarter  New_Dwelling_Completion_Number  Volume_of_Sales_Number  Value_of_Sales_MilEuro  Median_Price_Euro  Mean_Price_Euro  Housing_Stock_Number  Vacant_House_Number
# Carlow    2011Q1   17                              50.0                    6.8                     153205.000000      136542.666667    23165.00              3202.000000            1
# Monaghan  2016Q2   20                              108.0                   10.8                    95666.666667       103201.333333    25311.00              3126.000000            1
#           2015Q4   44                              125.0                   13.0                    100000.000000      104125.666667    25285.50              3153.200000            1
#           2015Q3   28                              84.0                    9.4                     85906.666667       106747.333333    25272.75              3166.800000            1
# ...

# %%
df.corr()
# Out:
#                                 New_Dwelling_Completion_Number  \
# New_Dwelling_Completion_Number                        1.000000
# Volume_of_Sales_Number                                0.885065
# Value_of_Sales_MilEuro                                0.924332
# Median_Price_Euro                                     0.670549
# Mean_Price_Euro                                       0.721722
# Housing_Stock_Number                                  0.762035
# Vacant_House_Number                                   0.510103
#
#                                 Volume_of_Sales_Number  \
# New_Dwelling_Completion_Number                0.885065
# Volume_of_Sales_Number                        1.000000
# Value_of_Sales_MilEuro                        0.976998
# Median_Price_Euro                             0.605806
# Mean_Price_Euro                               0.692252
# Housing_Stock_Number                          0.923966
# Vacant_House_Number                           0.672590
#
# ...
